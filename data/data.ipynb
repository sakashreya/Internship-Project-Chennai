# %%
import pandas as pd
accepted= pd.read_csv("/Users/shreya/Desktop/Loan Predictor/data/accepted_2007_to_2018Q4.csv")
rejected= pd.read_csv("/Users/shreya/Desktop/Loan Predictor/data/rejected_2007_to_2018Q4.csv")

print("Accepted:", accepted.shape)
print("Rejected:", rejected.shape)
# Out:
# /var/folders/sl/x31hqkds6dq5__0pw5k7mxmr0000gn/T/ipykernel_40623/3495656371.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   accepted= pd.read_csv("/Users/shreya/Desktop/Loan Predictor/data/accepted_2007_to_2018Q4.csv")
# Accepted: (2260701, 151)
# Rejected: (27648741, 9)

# %%
print(accepted.columns.tolist()[:20])
print(rejected.columns.tolist()[:20])
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc']
# ['Amount Requested', 'Application Date', 'Loan Title', 'Risk_Score', 'Debt-To-Income Ratio', 'Zip Code', 'State', 'Employment Length', 'Policy Code']

# %%
for col in ['dti', 'zip_code', 'addr_state']:
    print(col, '->', col in accepted.columns)
# Out:
# dti -> True
# zip_code -> True
# addr_state -> True
